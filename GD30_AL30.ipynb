# %% [markdown]
# <a href="https://colab.research.google.com/github/aperezb97/GD30-AL30/blob/main/GD30_AL30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **GRÁFICO PRECIO AL30 HISTÓRICO**

# %%
#Graficando la serie temporal con el dataframe imputado
fig,ax= plt.subplots(figsize=(30,10))
ax.plot(al30.fecha_al30, al30.al30c, label='AL30',linewidth=3)

ax.legend()
ax.grid()
ax.set_title('AL30')
ax.set_xlabel('Fecha')
ax.set_ylabel('Valor')
# Out:
# Text(0, 0.5, 'Valor')

# %% [markdown]
# # **GRÁFICO PRECIO GD30 HISTÓRICO**

# %%
#Graficando la serie temporal con el dataframe imputado
fig,ax= plt.subplots(figsize=(30,10))
ax.plot(gd30.fecha_gd30, gd30.gd30c, label='GD30',linewidth=3)

ax.legend()
ax.grid()
ax.set_title('GD30')
ax.set_xlabel('Fecha')
ax.set_ylabel('Valor')
# Out:
# Text(0, 0.5, 'Valor')

# %% [markdown]
# # **GRÁFICO PRECIOS GD30 Y AL30 - COMPARACIÓN**

# %%
#Graficando la serie temporal con el dataframe imputado
fig,ax= plt.subplots(figsize=(30,10))
ax.plot(gd30.fecha_gd30, gd30.gd30c, label='GD30',linewidth=3)
ax.plot(al30.fecha_al30, al30.al30c, label='AL30',linewidth=3,linestyle='--')


ax.legend()
ax.grid()
ax.set_title('GD30/AL30')
ax.set_xlabel('Fecha')
ax.set_ylabel('Valor')
# Out:
# Text(0, 0.5, 'Valor')

# %% [markdown]
# Prestar atención como el AL30 es mas barato que el GD30, aca es posible ver de manera simple el ratio a operar. Comprando AL30 y Vendiendo G30 esperando que esa relación vaya a promedios anteriores.

# %% [markdown]
# # **VOLUMEN OPERADO GD30 Y AL30**
#
# Es mucho mayor el volumen operado en el AL30, este es de mayor liquidez ya que se utiliza en el gobierno para operar el dolar MEP.

# %%
#Graficando la serie temporal con el dataframe imputado
fig,ax= plt.subplots(figsize=(30,10))
ax.plot(gd30.fecha_gd30, gd30.volumen_gd30, label='GD30',linewidth=3)
ax.plot(al30.fecha_al30, al30.volumen_al30, label='AL30',linewidth=3,linestyle='--')


ax.legend()
ax.grid()
ax.set_title('GD30/AL30 Volumen')
ax.set_xlabel('Fecha')
ax.set_ylabel('Valor')
# Out:
# Text(0, 0.5, 'Valor')

# %% [markdown]
# # **Datos estadísticos BONO AL30**
#
# - Count = Cantidad
# - Mean = Media
# - STD = Desviación estandar
# - Min = Precio Mínimo
# - 25%, 50%, 75% = Percentiles
# - Max = Precio Máximo

# %%
al30[['al30c']].describe()
# Out:
#             al30c
# count  503.000000
# mean    58.605060
# std      4.706752
# min     48.010000
# 25%     55.320000
# 50%     58.510000
# 75%     62.375000
# max     68.805000

# %% [markdown]
# # **Datos estadísticos BONO GD30**
#
# - Count = Cantidad
# - Mean = Media
# - STD = Desviación estandar
# - Min = Precio Mínimo
# - 25%, 50%, 75% = Percentiles
# - Max = Precio Máximo

# %%
gd30[['gd30c']].describe()
# Out:
#             gd30c
# count  503.000000
# mean    64.008549
# std      6.164289
# min     49.200000
# 25%     59.792500
# 50%     63.855000
# 75%     69.605000
# max     76.650000

# %% [markdown]
# # **Datos estadísticos RATIO AL30/GD30**
# - Count = Cantidad
# - Mean = Media
# - STD = Desviación estandar
# - Min = Precio Mínimo
# - 25%, 50%, 75% = Percentiles
# - Max = Precio Máximo
#
# ---

# %%
gd_al_percent[['porcentaje2']].describe()
# Out:
#        porcentaje2
# count   503.000000
# mean      0.917700
# std       0.037913
# min       0.841928
# 25%       0.886695
# 50%       0.909142
# 75%       0.942911
# max       1.009888

# %% [markdown]
# # **Datos estadísticos RATIO GD30/AL30**
# - Count = Cantidad
# - Mean = Media
# - STD = Desviación estandar
# - Min = Precio Mínimo
# - 25%, 50%, 75% = Percentiles
# - Max = Precio Máximo
#
# ---

# %%
gd_al_percent[['porcentaje']].describe()
# Out:
#        porcentaje
# count  503.000000
# mean     1.091499
# std      0.044128
# min      0.990209
# 25%      1.060546
# 50%      1.099938
# 75%      1.127783
# max      1.187750

# %% [markdown]
# # **CORRELACIÓN LINEAL ENTRE AMBOS BONOS**
#
# Tienen una correlación muy alta, debido a que son bonos muy parecidos y solo cambia la legislación.

# %%
#con seaborn
sns.lmplot(x='gd30c', y='al30c', data=gd_al_percent)
plt.show()

# %% [markdown]
# # **RATIO HISTÓRICO GD30/AL30**
#
# La división esta GD30/AL30.

# %%
#Graficando la serie temporal con el dataframe imputado
fig,ax= plt.subplots(figsize=(30,10))
ax.plot(gd_al_percent.fecha_al30, gd_al_percent.porcentaje, label='Relación',linewidth=3)

ax.legend()
ax.grid()
ax.set_title('Relación GD30/AL30')
ax.set_xlabel('Fecha')
ax.set_ylabel('Valor')
# Out:
# Text(0, 0.5, 'Valor')

# %% [markdown]
# # **RATIO DIVISIÓN GD30/AL30 CON MEDIAS MOVILES DE 50,100 Y 200**

# %%
#Graficando la serie temporal con el dataframe imputado
fig,ax= plt.subplots(figsize=(30,10))
ax.plot(gd_al_percent.fecha_al30, gd_al_percent.media200, label='Media200',linewidth=2, linestyle='--')
ax.plot(gd_al_percent.fecha_al30, gd_al_percent.media, label='Media100',linewidth=2, linestyle='--')
ax.plot(gd_al_percent.fecha_al30, gd_al_percent.media50, label='Media50',linewidth=2, linestyle='--')
ax.plot(gd_al_percent.fecha_al30, gd_al_percent.porcentaje, label='Relación',linewidth=3)

ax.legend()
ax.grid()
ax.set_title('Relación GD30/AL30 y Media')
ax.set_xlabel('Fecha')
ax.set_ylabel('Valor')
# Out:
# Text(0, 0.5, 'Valor')

# %% [markdown]
# # **RATIO AL30/GD30**
#
# Acá la división es AL30/GD30 para ver abajo y poder comparar los desvíos estandar.
#
# ---
#
#
#
# ---

# %%
#Graficando la serie temporal con el dataframe imputado
fig,ax= plt.subplots(figsize=(30,10))
#ax.plot(gd_al_percent.fecha_al30, gd_al_percent.media100.2, label='Media100',linewidth=2, linestyle='--')
ax.plot(gd_al_percent.fecha_al30, gd_al_percent.porcentaje2, label='Relación',linewidth=3)

ax.legend()
ax.grid()
ax.set_title('Relación GD30/AL30 y Media')
ax.set_xlabel('Fecha')
ax.set_ylabel('Valor')
# Out:
# Text(0, 0.5, 'Valor')

# %% [markdown]
# En sintesis, la relación se encuentra en que es barato comprar AL30 en comparación al GD30. Sigo la relación de los bonos y opero los ratios independientemente de como se encuentran los precios (gráficos arriba). No voy direccional hacia una tendencia, son los "famosos spread".
#
# GD30 se encuentra bajo la ley de New York, esto significa que es de menor riesgo en comparación al bono local y aqui es donde se encuentra en spread entre legislaciones.
#
# Los títulos públicos con mayor liquidez de nuestro mercado son los AL30, por su monto de emisión y por la operatoria de dólar MEP. A su vez en los globales el de mayor liquidez es el GD30 que tambien se utiliza para operar dólar MEP. En estos dos bonos es donde se da la mayor diferencia porcentual entre legislaciones, el AL30 es el bono que el gobierno usa para intervenir y, debido a estas intervenciones, se amplían las disparidades de precios.
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **SIMULACIÓN DE BONOS EN EL TIEMPO**
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **CÓDIGO EXTRA - INICIAL**
#
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
al30 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/GD30   AL30/AL30 - Cotizaciones historicas.csv')
gd30 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/GD30   AL30/GD30 - Cotizaciones historicas.csv')

# %%
#validamos la cantidad de variables Nan 
#con reset_index se asocia el index dentro del dataframe
conteo = al30.isna().sum().reset_index() 
conteo= conteo.rename(columns={0: "nulos"});
suma_nulos = conteo['nulos'].sum()
print('Valores Nan:',suma_nulos)
# Out:
# Valores Nan: 0

# %%
al30.columns = ['especie_al30', 'fecha_al30', 'apertura_al30', 'maximo_al30', 'minimo_al30', 'cierre_al30', 'volumen_al30',
       'timestamp_al30']
al30
# Out:
#     especie_al30  fecha_al30  apertura_al30  maximo_al30  minimo_al30  \
# 0           AL30  2020-09-08         6270.0       6350.0       6200.0
# 1           AL30  2020-09-09         6350.0       6440.0       6348.0
# 2           AL30  2020-09-10         6375.0       6428.5       6370.0
# 3           AL30  2020-09-11         6410.0       6505.0       6395.0
# 4           AL30  2020-09-14         6450.0       6450.0       6350.0
# ..           ...         ...            ...          ...          ...
# 498         AL30  2022-09-23         6359.0       6359.0       6123.0
# 499         AL30  2022-09-26         6159.0       6159.0       5820.0
# 500         AL30  2022-09-27         5890.0       5890.0       5446.0
# 501         AL30  2022-09-28         5455.0       5770.5       5330.5
# 502         AL30  2022-09-29         5725.0       5750.0       5518.5
#
#      cierre_al30  volumen_al30  timestamp_al30
# 0         6320.0      13314126      1599534000
# ...

# %%
al30['al30c'] = al30['cierre_al30']/100
al30
# Out:
#     especie_al30  fecha_al30  apertura_al30  maximo_al30  minimo_al30  \
# 0           AL30  2020-09-08         6270.0       6350.0       6200.0
# 1           AL30  2020-09-09         6350.0       6440.0       6348.0
# 2           AL30  2020-09-10         6375.0       6428.5       6370.0
# 3           AL30  2020-09-11         6410.0       6505.0       6395.0
# 4           AL30  2020-09-14         6450.0       6450.0       6350.0
# ..           ...         ...            ...          ...          ...
# 498         AL30  2022-09-23         6359.0       6359.0       6123.0
# 499         AL30  2022-09-26         6159.0       6159.0       5820.0
# 500         AL30  2022-09-27         5890.0       5890.0       5446.0
# 501         AL30  2022-09-28         5455.0       5770.5       5330.5
# 502         AL30  2022-09-29         5725.0       5750.0       5518.5
#
#      cierre_al30  volumen_al30  timestamp_al30  al30c
# 0         6320.0      13314126      1599534000  63.20
# ...

# %%
al30['fecha_al30']=pd.to_datetime(al30['fecha_al30'])
al30.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   especie_al30    503 non-null    object
#  1   fecha_al30      503 non-null    datetime64[ns]
#  2   apertura_al30   503 non-null    float64
#  3   maximo_al30     503 non-null    float64
#  4   minimo_al30     503 non-null    float64
#  5   cierre_al30     503 non-null    float64
#  6   volumen_al30    503 non-null    int64
#  7   timestamp_al30  503 non-null    int64
#  8   al30c           503 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(1)
# memory usage: 35.5+ KB

# %%
gd30.columns = ['especie_gd30', 'fecha_gd30', 'apertura_gd30', 'maximo_gd30', 'minimo_gd30', 'cierre_gd30', 'volumen_gd30',
       'timestamp_gd30']
gd30
# Out:
#     especie_gd30  fecha_gd30  apertura_gd30  maximo_gd30  minimo_gd30  \
# 0           GD30  2020-09-08         6200.0       6325.0       6200.0
# 1           GD30  2020-09-09         6400.0       6435.0       6356.0
# 2           GD30  2020-09-10         6390.0       6425.0       6375.0
# 3           GD30  2020-09-11         6425.0       6500.0       6395.0
# 4           GD30  2020-09-14         6385.0       6402.0       6355.0
# ..           ...         ...            ...          ...          ...
# 498         GD30  2022-09-23         7344.0       7365.0       7090.0
# 499         GD30  2022-09-26         7150.0       7150.0       6775.0
# 500         GD30  2022-09-27         6870.0       6870.0       6305.0
# 501         GD30  2022-09-28         6317.0       6675.0       6238.0
# 502         GD30  2022-09-29         6644.0       6644.0       6364.5
#
#      cierre_gd30  volumen_gd30  timestamp_gd30
# 0         6325.0       1477770      1599534000
# ...

# %%
gd30['gd30c'] = gd30['cierre_gd30']/100
gd30
# Out:
#     especie_gd30  fecha_gd30  apertura_gd30  maximo_gd30  minimo_gd30  \
# 0           GD30  2020-09-08         6200.0       6325.0       6200.0
# 1           GD30  2020-09-09         6400.0       6435.0       6356.0
# 2           GD30  2020-09-10         6390.0       6425.0       6375.0
# 3           GD30  2020-09-11         6425.0       6500.0       6395.0
# 4           GD30  2020-09-14         6385.0       6402.0       6355.0
# ..           ...         ...            ...          ...          ...
# 498         GD30  2022-09-23         7344.0       7365.0       7090.0
# 499         GD30  2022-09-26         7150.0       7150.0       6775.0
# 500         GD30  2022-09-27         6870.0       6870.0       6305.0
# 501         GD30  2022-09-28         6317.0       6675.0       6238.0
# 502         GD30  2022-09-29         6644.0       6644.0       6364.5
#
#      cierre_gd30  volumen_gd30  timestamp_gd30  gd30c
# 0         6325.0       1477770      1599534000  63.25
# ...

# %%
gd30['fecha_gd30']=pd.to_datetime(gd30['fecha_gd30'])
gd30.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   especie_gd30    503 non-null    object
#  1   fecha_gd30      503 non-null    datetime64[ns]
#  2   apertura_gd30   503 non-null    float64
#  3   maximo_gd30     503 non-null    float64
#  4   minimo_gd30     503 non-null    float64
#  5   cierre_gd30     503 non-null    float64
#  6   volumen_gd30    503 non-null    int64
#  7   timestamp_gd30  503 non-null    int64
#  8   gd30c           503 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(1)
# memory usage: 35.5+ KB

# %% [markdown]
# # **CÁLCULO EXTRA**
#
# ---
#
#
#
# ---

# %%
gd_al_percent['media200'] = gd_al_percent['porcentaje'].rolling(200).mean()
gd_al_percent
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     fecha_al30  gd30c  al30c  porcentaje   media50     media  media200
# 0   2020-09-08  63.25  63.20    1.000791       NaN       NaN       NaN
# 1   2020-09-09  63.80  63.77    1.000470       NaN       NaN       NaN
# 2   2020-09-10  64.20  64.15    1.000779       NaN       NaN       NaN
# 3   2020-09-11  64.30  64.01    1.004531       NaN       NaN       NaN
# 4   2020-09-14  63.80  63.91    0.998279       NaN       NaN       NaN
# ..         ...    ...    ...         ...       ...       ...       ...
# 498 2022-09-23  71.50  61.50    1.162602  1.129827  1.135131  1.127597
# ...

# %%
gd_al_percent['media100.2'] = gd_al_percent['porcentaje2'].rolling(100).mean()
gd_al_percent
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     fecha_al30  gd30c  al30c  porcentaje   media50     media  media200  \
# 0   2020-09-08  63.25  63.20    1.000791       NaN       NaN       NaN
# 1   2020-09-09  63.80  63.77    1.000470       NaN       NaN       NaN
# 2   2020-09-10  64.20  64.15    1.000779       NaN       NaN       NaN
# 3   2020-09-11  64.30  64.01    1.004531       NaN       NaN       NaN
# 4   2020-09-14  63.80  63.91    0.998279       NaN       NaN       NaN
# ..         ...    ...    ...         ...       ...       ...       ...
# 498 2022-09-23  71.50  61.50    1.162602  1.129827  1.135131  1.127597
# ...

# %%
gd_al_percent['porcentaje2'] = gd_al_percent['al30c']/gd_al_percent['gd30c']
gd_al_percent
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     fecha_al30  gd30c  al30c  porcentaje  porcentaje2
# 0   2020-09-08  63.25  63.20    1.000791     0.999209
# 1   2020-09-09  63.80  63.77    1.000470     0.999530
# 2   2020-09-10  64.20  64.15    1.000779     0.999221
# 3   2020-09-11  64.30  64.01    1.004531     0.995490
# 4   2020-09-14  63.80  63.91    0.998279     1.001724
# ..         ...    ...    ...         ...          ...
# 498 2022-09-23  71.50  61.50    1.162602     0.860140
# 499 2022-09-26  68.00  58.59    1.160608     0.861618
# 500 2022-09-27  63.51  54.80    1.158942     0.862856
# ...

# %%
import numpy as np

# %%
gd_al_percent['porcentaje'] = gd_al_percent['gd30c']/gd_al_percent['al30c']
gd_al_percent
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     fecha_al30  gd30c  al30c  porcentaje
# 0   2020-09-08  63.25  63.20    1.000791
# 1   2020-09-09  63.80  63.77    1.000470
# 2   2020-09-10  64.20  64.15    1.000779
# 3   2020-09-11  64.30  64.01    1.004531
# 4   2020-09-14  63.80  63.91    0.998279
# ..         ...    ...    ...         ...
# 498 2022-09-23  71.50  61.50    1.162602
# 499 2022-09-26  68.00  58.59    1.160608
# 500 2022-09-27  63.51  54.80    1.158942
# 501 2022-09-28  66.60  57.30    1.162304
# 502 2022-09-29  63.90  55.90    1.143113
#
# [503 rows x 4 columns]

# %%
gd_al_percent = gd_al[['fecha_al30','gd30c','al30c']]
gd_al_percent
# Out:
#     fecha_al30  gd30c  al30c
# 0   2020-09-08  63.25  63.20
# 1   2020-09-09  63.80  63.77
# 2   2020-09-10  64.20  64.15
# 3   2020-09-11  64.30  64.01
# 4   2020-09-14  63.80  63.91
# ..         ...    ...    ...
# 498 2022-09-23  71.50  61.50
# 499 2022-09-26  68.00  58.59
# 500 2022-09-27  63.51  54.80
# 501 2022-09-28  66.60  57.30
# 502 2022-09-29  63.90  55.90
#
# [503 rows x 3 columns]

# %%
gd_al = pd.concat([gd30,al30], axis=1)
gd_al
# Out:
#     especie_gd30 fecha_gd30  apertura_gd30  maximo_gd30  minimo_gd30  \
# 0           GD30 2020-09-08         6200.0       6325.0       6200.0
# 1           GD30 2020-09-09         6400.0       6435.0       6356.0
# 2           GD30 2020-09-10         6390.0       6425.0       6375.0
# 3           GD30 2020-09-11         6425.0       6500.0       6395.0
# 4           GD30 2020-09-14         6385.0       6402.0       6355.0
# ..           ...        ...            ...          ...          ...
# 498         GD30 2022-09-23         7344.0       7365.0       7090.0
# 499         GD30 2022-09-26         7150.0       7150.0       6775.0
# 500         GD30 2022-09-27         6870.0       6870.0       6305.0
# 501         GD30 2022-09-28         6317.0       6675.0       6238.0
# 502         GD30 2022-09-29         6644.0       6644.0       6364.5
#
#      cierre_gd30  volumen_gd30  timestamp_gd30  gd30c especie_al30 fecha_al30  \
# ...

# %%
al30.columns
# Out:
# Index(['especie', 'fecha', 'apertura', 'maximo', 'minimo', 'cierre', 'volumen',
#        'timestamp'],
#       dtype='object')
